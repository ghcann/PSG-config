# %%
# Filename 
psg_filename = 'filename'
#HDF5 Directory
directory = '/file_directory'
# Open HDF5 file
hdf5_file = h5py.File("%s%s" % (directory,psg_filename))
# Assign spectral index
i = index
# Assign start or end spectra index
l = 0
# Set planet
planet = 'Mars'
# Set geometry type
geometry_type = 'Solar'
# Assign spacecraft altitude ObsAlt
obsalt = hdf5_file["/Geometry/ObsAlt"]
 # Assign Point0 TangentAltSurface attribute
tanaltsur = hdf5_file["/Geometry/Point0/TangentAltSurface"]
# Assign Point0 SurfaceRadius attribute
surrad = hdf5_file["/Geometry/Point0/SurfaceRadius"]
# Assign Geometry SubObsLat attribute
subobslat = hdf5_file["/Geometry/SubObsLat"]
# Assign Geometry SubObsLon attribute
subobslon = hdf5_file["/Geometry/SubObsLon"]
# Assign Geometry Point0 Lat attribute
point0_lat = hdf5_file["/Geometry/Point0/Lat"]
# Assign Geometry Point0 Lon attribute
point0_lon = hdf5_file["/Geometry/Point0/Lon"]
# Set the number of longitude and latitude points
n_lat_lon = 10000
# Set the number of atmospheric layers
n_atm_layers = 100
# Set planet_radius in km
planet_radius = 3.3762e3
# Initialise spacecraft to tangent line latitude array for start of observation
dl_list_start = []
# Initialise spacecraft to tangent line latitude array
n_spectra = np.shape(point0_lon)
# Set date
date_time = hdf5_file["/DateTime"]
# Set solar longitude
ls = hdf5_file["/Geometry/LSubS"]
# Set the sub solar latitude
subsollat = hdf5_file["/Geometry/SubSolLat"]
# Set the sub solar longitude
subsollon = hdf5_file["/Geometry/SubSolLon"]
# Set gravity unit 
gravity_unit = 'g'
# Set gravity
gravity = 3.757
# Set the spacecraft velocity 
obs_velocity = hdf5_file["/Geometry/SpdObsSun"]
# Set the solar radius
solar_radius = 1.0
# Set the geometry reference
geometry_reference = 'TGO'
# Set the distance to the Sun in astronomical units
distance_to_sun = hdf5_file["/Geometry/DistToSun"]
# Set the object star velocity
object_star_velocity = hdf5_file["/Geometry/SpdTargetSun"]
# Set the type of star
star_type = 'G'
# Set the star temperature
star_temp = 5778
# Set object rotational period
object_period = 1.025957
# Set phase 
phase = 0.0
# Set solar angle
solar_angle = 90.0
# Set object angle
obs_angle = 0.0 
# Set the planet fraction
set_planet_fraction = 0.0
# Set the geometry star distance metric  
geometry_star_distance = -1.0
# Set the geometry rotation
altitude_units = 'km'
# Set the atmospheric 
atmospheric_unit = 'scl'
# Set the pressure profile
pressure = tm.pressureProfile/1e5
# Set the temperature profile
temperature = tm.temperatureProfile
# Set the star fraction
star_fraction = 0.0
# Set the geometry rotation
geometry_rotation = 0.0
# Set the observation altitude
obs_alt = hdf5_file["/Geometry/ObsAlt"]
# Set the pressure unit
pressure_unit = 'mbar'
# Set the tangent height
tangent_height = hdf5_file["/Geometry/Point0/TangentAlt"]
# Set the disk angles
disk_angles = 1.0
# Set geometry offset North South
offset_ns = 0.0
# Set geometry offset East West
offset_ew = 0.0
# Set the offset unit
offset_unit = 'arcsec'
# Set the stellar magnitude
stellar_magnitude = 0.0
# Set the MCD version title
mcd_version = 'Mars Climate Database, Millour et al. 2015'
# Set atmospheric structure
atmospheric_structure = 'Equilibrium'
# Set atmospheric weight
atmospheric_weight = 43.63
CO2 = tm.chemistry.activeGasMixProfile[0]
H2O = tm.chemistry.activeGasMixProfile[1]
CH4 = tm.chemistry.activeGasMixProfile[2]
# Number of atmospheric aerosols
no_atmospheric_aerosols = 2
# Set the atmospheric aerosol type
atmospheric_aerosols = 'CRISM_Wolff[reff=1.5um 0.44-98.54um],CRISM_Wolff[reff=2.0um 0.31-99.57um]'
# Set the aerosol names
aerosol_names = 'Dust,WaterIce'
# Set the number of gases 
no_gases = 3
# Set the molecules included
molecules = 'CO2,H2O,CH4'
# Set the atmospheric abundance metric
atmospheric_abundance = 1
# Set the atmospheric aerosol abundance metric
atmospheric_aerosol_abundance = 1
# Set the absorption cross sections
abs_cross_sections = 'HIT[2],HIT[1],HIT[6]'
# Set tau metric
psg_tau = 1
# Set atmospheric nmax
nmax = 0
# Set atmospheric nmin
nmin = 0
# Set the surface temperature 
surface_temperature = 193.35
# Set the surface albedo
surface_albedo = 0.2445
# Set nsurf 
nsurf = 0
# Set surface phase G
phase_g = 0
# Set the surface gas ratio 
surface_gas_ratio = 1.0
# Set the surface_gas_unit
surface_gas_unit = 'ratio'
# Set the generator instrument
generator_instrument = 'ExoMars_NOMAD-SO: ExoMars_NOMAD-SO: The Solar Occultation (SO) channel is the primary occultation spectrometer of the NOMAD instrument onboard the ExoMars / Trace-Gas-Orbiter (TGO) mission. It is a high-resolution (RP 20,000) grating spectrometer coupled with a AOTF filter. It has an instantaneous spectral grasp of  27 cm-1 covering the 2200-5000 cm-1 (2.0 to 4.5 um) spectral region.'
# Set the radiation units 
radiation_units = 'rif'
# Set use stellar continuum
stellar_continuum = 'N'
# Set the noise time metric
noise_time = 4.00e-03
# Set the number of noise frames 
no_noise_frames = 12
# Set the number of noise pixels 
noise_pixels = 5
# Set the range unit
range_unit = 'um'
# Set the instrument resolution 
instrument_resolution = 0.30382
# Set the resolution unit
resolution_unit = 'cm'
# Set the noise eoff metric 
noise_eoff = 1
# Set the telescope diameter
telescope_diameter = 0.02
# Set the generator beam
generator_beam = 1.5 
# Set the generator beam unit
beam_unit = 'arcmin'
# Set the generator_telescope
generator_telescope = 'AOTF'
# Set use gas model
use_gas_model = 'Y'
# Set use continuum model
use_continuum_model = 'Y'
# Set the telescope 1 wavenumber metric
telescope_1_wavenumber = 3342
# Set the telescope 1 wavenumber width
telescope_1_wavenumber_width = 22
# Set the telescope 2 wavenumber metric
telescope_2_wavenumber = 3342
# Set the telescope 2 wavenumber width
telescope_2_wavenumber_width = 22
# Set the telescope_2 metric
telescope_2 = 2
# Set the generator trans metric
generator_trans_metric = '02-01'
# Set the generator apply trans metric 
trans_apply = 'N'
# Set the generator show trans metric 
trans_show = 'N'
# Use log radiation
generator_log_rad = 'N'
# Include generator noise
include_generator_noise = 'NO'
# Set generator noise 1
generator_noise_1 = 0.0
# Set generator noise 2
generator_noise_2 = 0.0
# Set the generator noiseoemis metric
noiseoemis = 0.0
# Set the generator noise temperature 
generator_noise_temp = 250

# %%
date_time_str = str(date_time[i])
date_time_str_formatted = date_time_str[2:-1]
date_time_obj = datetime.datetime.strptime(date_time_str_formatted, '%Y %b %d %H:%M:%S.%f')
print('Date:', date_time_obj.date())

# %%
# Create NASA PSG config file using file metadata
text_file = open("nasa_psg_%s.txt" % psg_filename, "w")
text_file.write("<OBJECT>%s\n" % planet)
text_file.write("<OBJECT-NAME>%s\n" % planet)
text_file.write("<OBJECT-DATE>%s\n" % date_time_obj)
text_file.write("<OBJECT-DIAMETER>%e\n" % (2*planet_radius))
text_file.write("<OBJECT-GRAVITY>%e\n" % gravity)
text_file.write("<OBJECT-GRAVITY-UNIT>%s\n" % gravity_unit)
text_file.write("<OBJECT-SEASON>%e\n" % ls[i,l])
text_file.write("<OBJECT-SOLAR-LONGITUDE>%e\n" % (subsollat[i,l] + 180))
text_file.write("<OBJECT-SOLAR-LATITUDE>%e\n" % subsollon[i,l])
text_file.write("<OBJECT-OBS-LONGITUDE>%e\n" % (subobslon[i,l] + 180))
text_file.write("<OBJECT-OBS-LATITUDE>%e\n" % subobslat[i,l])
text_file.write("<OBJECT-OBS-VELOCITY>%e\n" % obs_velocity[i,l])
text_file.write("<OBJECT-STAR-RADIUS>%e\n" % solar_radius)
text_file.write("<OBJECT-STAR-DISTANCE>%e\n" % distance_to_sun[i,l])
text_file.write("<OBJECT-STAR-VELOCITY>%e\n" % object_star_velocity[i,l])
text_file.write("<OBJECT-STAR-TEMPERATURE>%d\n" % star_temp)
text_file.write("<OBJECT-STAR-TYPE>%s\n" % star_type)
text_file.write("<OBJECT-PERIOD>%e\n" % object_period) 
text_file.write("<GEOMETRY-PHASE>%e\n" % phase)
text_file.write("<GEOMETRY-SOLAR-ANGLE>%e\n" % solar_angle)
text_file.write("<GEOMETRY-OBS-ANGLE>%e\n" % obs_angle)
text_file.write("<GEOMETRY-PLANET-FRACTION>%e\n" % set_planet_fraction)
text_file.write("<GEOMETRY-STAR-DISTANCE>%e\n" % geometry_star_distance)
text_file.write("<GEOMETRY-STAR-FRACTION>%e\n" % star_fraction)
text_file.write("<GEOMETRY-ROTATION>%e,%e\n" % (geometry_rotation,geometry_rotation))
text_file.write("<GEOMETRY>%s\n" % geometry_type)
text_file.write("<GEOMETRY-REF>%s\n" % geometry_reference)
text_file.write("<GEOMETRY-OBS-ALTITUDE>%e\n" % (obs_alt[i,l] - planet_radius))
text_file.write("<GEOMETRY-ALTITUDE-UNIT>%s\n" % altitude_units)
text_file.write("<GEOMETRY-USER-PARAM>%e\n" % tangent_height[i,l])
text_file.write("<GEOMETRY-DISK-ANGLES>%e\n" % disk_angles)
text_file.write("<GEOMETRY-OFFSET-NS>%e\n" % offset_ns)
text_file.write("<GEOMETRY-OFFSET-EW>%e\n" % offset_ew)
text_file.write("<GEOMETRY-OFFSET-UNIT>%s\n" % offset_unit)
text_file.write("<GEOMETRY-STELLAR-TYPE>%s\n" % star_type)
text_file.write("<GEOMETRY-STELLAR-TEMPERATURE>%e\n" % star_temp)
text_file.write("<GEOMETRY-STELLAR-MAGNITUDE>%e\n" % stellar_magnitude)
text_file.write("<ATMOSPHERE-DESCRIPTION>%s\n" % mcd_version)
text_file.write("<ATMOSPHERE-STRUCTURE>%s\n" % atmospheric_structure)
text_file.write("<ATMOSPHERE-WEIGHT>%e\n" % atmospheric_weight)
text_file.write("<ATMOSPHERE-PUNIT>%s\n" % pressure_unit)
text_file.write("<ATMOSPHERE-NGAS>%d\n" % no_gases)
text_file.write("<ATMOSPHERE-GAS>%s\n" % molecules)
text_file.write("<ATMOSPHERE-TYPE>%s\n" % str(abs_cross_sections))
text_file.write("<ATMOSPHERE-ABUN>%e,%e,%s\n" % (atmospheric_abundance,atmospheric_abundance,atmospheric_abundance))
text_file.write("<ATMOSPHERE-UNIT>%s,%s,%s\n" % (atmospheric_unit,atmospheric_unit,atmospheric_unit))
text_file.write("<ATMOSPHERE-LAYERS-MOLECULES>%s\n" % molecules)
text_file.write("<ATMOSPHERE-PRESSURE>%e\n" % (pressure[0]*1000))
text_file.write("<ATMOSPHERE-LAYERS>%d\n" % n_atm_layers)
# Create atmospheric profile
for j in range(n_atm_layers):
    # <ATMOSPHERE-LAYER-layer_number>pressure,temperature,CO2,H2O,CH4
    text_file.write("<ATMOSPHERE-LAYER-%d>%e,%e,%e,%e,%e\n" % (j+1,pressure[j],temperature[j],CO2[j],H2O[j],CH4[j])) 
#text_file.write("<ATMOSPHERE-NAERO>%d\n" % no_atmospheric_aerosols)
#text_file.write("<ATMOSPHERE-AEROS>%s\n" % aerosol_names)
#text_file.write("<ATMOSPHERE-ATYPE>%s,%s\n" % (atmospheric_aerosols,atmospheric_aerosols))
#text_file.write("<ATMOSPHERE-AABUN>%e,%e\n" % (atmospheric_aerosol_abundance,atmospheric_aerosol_abundance))
#text_file.write("<ATMOSPHERE-AUNIT>%s,%s\n" % (atmospheric_unit,atmospheric_unit))
#text_file.write("<ATMOSPHERE-ASIZE>1,1\n")
#text_file.write("<ATMOSPHERE-ASUNI>%s,%s\n" % (atmospheric_unit,atmospheric_unit))
text_file.write("<ATMOSPHERE-TEMPERATURE>%e\n" % temperature[0])
text_file.write("<ATMOSPHERE-TAU>%f\n" % psg_tau)
text_file.write("<ATMOSPHERE-NMAX>%f\n" % nmax)
text_file.write("<ATMOSPHERE-LMAX>%f\n" % nmin)
text_file.write("<SURFACE-TEMPERATURE>%f\n" % surface_temperature)
text_file.write("<SURFACE-ALBEDO>%f\n" % surface_albedo)
text_file.write("<SURFACE-EMISSIVITY>%f\n" % (1-surface_albedo))
text_file.write("<SURFACE-NSURF>%f\n" % nsurf)
text_file.write("<SURFACE-PHASEG>%f\n" % phase_g)
text_file.write("<SURFACE-GAS-RATIO>%f\n" % surface_gas_ratio)
text_file.write("<SURFACE-GAS-UNIT>%s\n" % surface_gas_unit)
text_file.write("<GENERATOR-INSTRUMENT>%s\n" % generator_instrument)
text_file.write("<GENERATOR-RADUNITS>%s\n" % radiation_units)
text_file.write("<GENERATOR-CONT-STELLAR>%s\n" % stellar_continuum)
text_file.write("<GENERATOR-NOISETIME>%e\n" % noise_time)
text_file.write("<GENERATOR-NOISEFRAMES>%d\n" % no_noise_frames)
text_file.write("<GENERATOR-NOISEPIXELS>%d\n" % noise_pixels)
text_file.write("<GENERATOR-RANGE1>%e\n" % (10000/3035.08159732))
text_file.write("<GENERATOR-RANGE2>%e\n" % (10000/3011.08514701))
text_file.write("<GENERATOR-RANGEUNIT>%s\n" % range_unit)
text_file.write("<GENERATOR-RESOLUTION>%e\n" % instrument_resolution)
text_file.write("<GENERATOR-RESOLUTIONUNIT>%s\n" % resolution_unit)
text_file.write("<GENERATOR-NOISEOEFF>%d\n" % noise_eoff)
text_file.write("<GENERATOR-DIAMTELE>%e\n" % telescope_diameter)
text_file.write("<GENERATOR-BEAM>%e\n" % generator_beam)
text_file.write("<GENERATOR-BEAM-UNIT>%s\n" % beam_unit)
text_file.write("<GENERATOR-TELESCOPE>%s\n" % generator_telescope)
text_file.write("<GENERATOR-TELESCOPE1>%e,%e\n" % (telescope_1_wavenumber, telescope_1_wavenumber_width))
text_file.write("<GENERATOR-TELESCOPE2>%d\n" % telescope_2)
text_file.write("<GENERATOR-TELESCOPE3>%e,%e\n" % (telescope_2_wavenumber, telescope_2_wavenumber_width))
text_file.write("<GENERATOR-GAS-MODEL>%s\n" % use_gas_model)
text_file.write("<GENERATOR-CONT-MODEL>%s\n" % use_continuum_model)
text_file.write("<GENERATOR-TRANS>%s\n" % generator_trans_metric)
text_file.write("<GENERATOR-TRANS-APPLY>%s\n" % trans_apply)
text_file.write("<GENERATOR-TRANS-SHOW>%s\n" % trans_show)
text_file.write("<GENERATOR-LOGRAD>%s\n" % generator_log_rad)
text_file.write("<GENERATOR-NOISE>%s\n" % include_generator_noise)
text_file.write("<GENERATOR-NOISE1>%e\n" % generator_noise_1)
text_file.write("<GENERATOR-NOISE2>%e\n" % generator_noise_2)
text_file.write("<GENERATOR-NOISEOEMIS>%e\n" % noiseoemis)
text_file.write("<GENERATOR-NOISEOTEMP>%e\n" % generator_noise_temp)
text_file.close()

# %%
# Run curl --data-urlencode file@nasa_psg.txt https://psg.gsfc.nasa.gov/api.php -o nasa_psg_output.txt
# curl -d type=trn -d whdr=n --data-urlencode file@nasa_psg.txt https://psg.gsfc.nasa.gov/api.php -o nasa_psg_output.txt
print('curl -d type=trn -d whdr=n --data-urlencode file@nasa_psg_%s.txt https://psg.gsfc.nasa.gov/api.php -o nasa_psg_output_%s.txt' % (psg_filename,psg_filename))

# %%
#Plot spectra 
plt.figure()
mpl.rcParams.update({'font.size': 7}) 
text_file = np.loadtxt("psg_output_%s.txt" % psg_filename)
plt.plot(10000/text_file[:,0],text_file[:,2],label='PSG', color='r', linewidth=0.5)
plt.ylabel('Transmittance')
plt.xlabel('Wavenumber [cm-1]')
plt.title('Simulated PSG for NOMAD SO channel \n solar occultation for %s filename\n' % psg_filename)
plt.legend()
plt.show()
